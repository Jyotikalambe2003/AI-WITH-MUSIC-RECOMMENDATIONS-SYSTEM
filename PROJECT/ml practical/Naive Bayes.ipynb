# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
df=pd.read_csv("titanic.csv")

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.drop(columns=["name","sibsp","ticket","parch","cabin","embarked","boat","body","home.dest"],inplace=True)

# %%
df
# Out:
#       pclass  survived     sex    age      fare
# 0          1         1  female  29.00  211.3375
# 1          1         1    male   0.92  151.5500
# 2          1         0  female   2.00  151.5500
# 3          1         0    male  30.00  151.5500
# 4          1         0  female  25.00  151.5500
# ...      ...       ...     ...    ...       ...
# 1304       3         0  female  14.50   14.4542
# 1305       3         0  female    NaN   14.4542
# 1306       3         0    male  26.50    7.2250
# 1307       3         0    male  27.00    7.2250
# 1308       3         0    male  29.00    7.8750
#
# [1309 rows x 5 columns]

# %%
y=df["survived"]# output
x=df[["pclass","sex","age","fare"]]

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: survived, Length: 1309, dtype: int64

# %%
x
# Out:
#       pclass     sex    age      fare
# 0          1  female  29.00  211.3375
# 1          1    male   0.92  151.5500
# 2          1  female   2.00  151.5500
# 3          1    male  30.00  151.5500
# 4          1  female  25.00  151.5500
# ...      ...     ...    ...       ...
# 1304       3  female  14.50   14.4542
# 1305       3  female    NaN   14.4542
# 1306       3    male  26.50    7.2250
# 1307       3    male  27.00    7.2250
# 1308       3    male  29.00    7.8750
#
# [1309 rows x 4 columns]

# %%
dummies=pd.get_dummies(x["sex"])
dummies
# Out:
#       female   male
# 0       True  False
# 1      False   True
# 2       True  False
# 3      False   True
# 4       True  False
# ...      ...    ...
# 1304    True  False
# 1305    True  False
# 1306   False   True
# 1307   False   True
# 1308   False   True
#
# [1309 rows x 2 columns]

# %%
x=pd.concat([x,dummies],axis="columns")

# %%
x.drop(columns=["sex"],inplace=True)

# %%
x
# Out:
#       pclass    age      fare  female   male
# 0          1  29.00  211.3375    True  False
# 1          1   0.92  151.5500   False   True
# 2          1   2.00  151.5500    True  False
# 3          1  30.00  151.5500   False   True
# 4          1  25.00  151.5500    True  False
# ...      ...    ...       ...     ...    ...
# 1304       3  14.50   14.4542    True  False
# 1305       3    NaN   14.4542    True  False
# 1306       3  26.50    7.2250   False   True
# 1307       3  27.00    7.2250   False   True
# 1308       3  29.00    7.8750   False   True
#
# [1309 rows x 5 columns]

# %%
# get any null value
x.columns[x.isna().any()]
# Out:
# Index(['age', 'fare'], dtype='object')

# %%
x["age"].head(50)
# Out:
# 0     29.00
# 1      0.92
# 2      2.00
# 3     30.00
# 4     25.00
# 5     48.00
# 6     63.00
# 7     39.00
# 8     53.00
# 9     71.00
# 10    47.00
# 11    18.00
# 12    24.00
# 13    26.00
# 14    80.00
# 15      NaN
# 16    24.00
# 17    50.00
# 18    32.00
# 19    36.00
# 20    37.00
# 21    47.00
# 22    26.00
# 23    42.00
# 24    29.00
# 25    25.00
# 26    25.00
# 27    19.00
# 28    35.00
# 29    28.00
# 30    45.00
# 31    40.00
# 32    30.00
# 33    58.00
# 34    42.00
# 35    45.00
# 36    22.00
# 37      NaN
# 38    41.00
# 39    48.00
# 40      NaN
# 41    44.00
# 42    59.00
# 43    60.00
# 44    41.00
# 45    45.00
# 46      NaN
# 47    42.00
# 48    53.00
# 49    36.00
# Name: age, dtype: float64

# %%
x["age"]=x["age"].fillna(x["age"].mean())

# %%
x["fare"]=x["fare"].fillna(x["fare"].mean())

# %%
x.rename(columns={0:"male",1:"female"},inplace=True)

# %%
x
# Out:
#       pclass        age      fare  female   male
# 0          1  29.000000  211.3375    True  False
# 1          1   0.920000  151.5500   False   True
# 2          1   2.000000  151.5500    True  False
# 3          1  30.000000  151.5500   False   True
# 4          1  25.000000  151.5500    True  False
# ...      ...        ...       ...     ...    ...
# 1304       3  14.500000   14.4542    True  False
# 1305       3  29.881138   14.4542    True  False
# 1306       3  26.500000    7.2250   False   True
# 1307       3  27.000000    7.2250   False   True
# 1308       3  29.000000    7.8750   False   True
#
# [1309 rows x 5 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,train_size=0.8,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1047, 5), (262, 5), (1047,), (262,))

# %%
x_train
# Out:
#       pclass        age      fare  female   male
# 1118       3  25.000000    7.9250   False   True
# 44         1  41.000000  134.5000    True  False
# 1072       3  29.881138    7.7333   False   True
# 1130       3  18.000000    7.7750    True  False
# 574        2  29.000000   21.0000   False   True
# ...      ...        ...       ...     ...    ...
# 763        3   0.170000   20.5750    True  False
# 835        3  29.881138    8.0500   False   True
# 1216       3  29.881138    7.7333    True  False
# 559        2  20.000000   36.7500    True  False
# 684        3  32.000000   15.5000    True  False
#
# [1047 rows x 5 columns]

# %%
model=GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(x_test,y_test)
# Out:
# 0.7748091603053435

# %%
x_test
# Out:
#       pclass        age     fare  female   male
# 1139       3  38.000000   7.8958   False   True
# 533        2  21.000000  21.0000    True  False
# 459        2  42.000000  27.0000   False   True
# 1150       3  29.881138  14.5000   False   True
# 393        2  25.000000  31.5000   False   True
# ...      ...        ...      ...     ...    ...
# 753        3  22.000000   8.0500   False   True
# 1052       3  29.881138   7.8958   False   True
# 426        2  30.000000  13.0000   False   True
# 554        2  26.000000  13.0000   False   True
# 1213       3  29.881138   8.0500   False   True
#
# [262 rows x 5 columns]

# %%
y_test
# Out:
# 1139    0
# 533     1
# 459     0
# 1150    0
# 393     0
#        ..
# 753     0
# 1052    0
# 426     0
# 554     0
# 1213    0
# Name: survived, Length: 262, dtype: int64

# %%
y_predict=model.predict(x_test[:10])

# %%
model.predict_proba(x_test[:10])
# Out:
# array([[0.98823162, 0.01176838],
#        [0.04632163, 0.95367837],
#        [0.97376574, 0.02623426],
#        [0.98851649, 0.01148351],
#        [0.97338507, 0.02661493],
#        [0.06398776, 0.93601224],
#        [0.91062116, 0.08937884],
#        [0.90035412, 0.09964588],
#        [0.96623289, 0.03376711],
#        [0.98843201, 0.01156799]])
